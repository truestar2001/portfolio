# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook

df = pd.read_csv('./output.csv')
df.head(5)
# Out:
#       ID_REF  GSM151259  GSM151260  GSM151261  GSM151262  GSM151263  \
# 0  1007_s_at   8.598882   8.523999   9.151616   8.619172   8.925920
# 1    1053_at   6.848821   6.733007   7.283071   6.460641   6.213657
# 2     117_at   5.141545   6.000812   4.847115   5.887788   5.716745
# 3     121_at   5.877394   5.956416   6.031219   6.124468   6.323811
# 4  1255_g_at   2.026605   1.880405   1.711745   1.686634   1.828178
#
#    GSM151264  GSM151265  GSM151266  GSM151267  ...  GSM151336  GSM151337  \
# 0   9.616641   9.450158   8.689728   8.925450  ...   8.810666   9.876917
# 1   5.787412   6.121179   6.862273   6.313435  ...   5.944039   6.236836
# 2   5.727272   5.307079   4.721051   5.420677  ...   4.669397   5.468497
# 3   6.231946   6.166422   5.987948   6.185425  ...   5.631996   6.183228
# 4   1.938201   1.905041   1.829138   1.942084  ...   1.686603   1.850454
#
#    GSM151338  GSM151339  GSM151340  GSM151341  GSM151342  GSM151343  \
# 0   9.147250   8.984707   8.769044   7.979955   8.847163   8.667560
# 1   6.280118   6.368237   6.867288   6.934095   5.633570   6.562457
# 2   4.565172   4.246593   5.178889   4.718608   5.210969   4.860924
# 3   6.008688   6.200976   6.249420   6.215371   6.558142   5.956507
# 4   1.709789   1.946195   1.760028   1.816439   1.810483   1.888790
#
#    GSM151344  GSM151345
# 0   9.285763   9.015781
# 1   7.143927   6.703256
# 2   4.545735   5.107950
# 3   6.411773   5.660290
# 4   1.726359   1.731505
#
# [5 rows x 88 columns]

# %%
df = df.transpose()
df = df.rename(columns=df.iloc[0])
df.drop(df.index[0], inplace=True)
df['cancer'] = 0
df.drop(df.columns[-2], axis=1, inplace = True)
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#           1007_s_at   1053_at    117_at    121_at 1255_g_at   1294_at  \
# GSM151259  8.598882  6.848821  5.141545  5.877394  2.026605  6.663656
# GSM151260  8.523999  6.733007  6.000812  5.956416  1.880405  6.551523
# GSM151261  9.151616  7.283071  4.847115  6.031219  1.711745  5.901029
# GSM151262  8.619172  6.460641  5.887788  6.124468  1.686634  6.351176
# GSM151263   8.92592  6.213657  5.716745  6.323811  1.828178  6.276506
#
#             1316_at   1320_at 1405_i_at   1431_at  ... AFFX-r2-Ec-bioD-5_at  \
# GSM151259  3.334369  3.292818  6.333143  2.777916  ...            10.218104
# GSM151260  3.330929  3.010386  5.685335   2.83521  ...             9.976598
# GSM151261  3.218729  2.588752  7.524602  2.330878  ...            10.454041
# GSM151262  3.397831  3.148233  5.594144  2.884427  ...            10.175746
# GSM151263  3.612326  3.204559  4.509043  2.546576  ...            10.712507
#
#           AFFX-r2-P1-cre-3_at AFFX-r2-P1-cre-5_at AFFX-ThrX-3_at  \
# GSM151259           12.182117           12.002252       2.390509
# GSM151260           12.083715           11.794364       2.349284
# GSM151261           12.334606           12.034793       2.264607
# GSM151262           12.317215           11.963655       2.080147
# GSM151263           12.522815           12.370773       2.269168
#
#           AFFX-ThrX-5_at AFFX-ThrX-M_at AFFX-TrpnX-3_at AFFX-TrpnX-5_at  \
# GSM151259       2.225881       1.868638        1.629952        1.948431
# GSM151260       2.214763       1.764588        1.721504        1.858394
# GSM151261       2.138744       1.617288        1.751432        1.831504
# GSM151262       2.276124       1.875681        1.712929        1.925453
# GSM151263       2.166079       1.842607        1.625314        1.728776
#
#           AFFX-TrpnX-M_at cancer
# GSM151259        1.791261      0
# GSM151260        2.053418      0
# GSM151261        2.025358      0
# GSM151262        1.719681      0
# GSM151263        1.972289      0
#
# [5 rows x 54676 columns]

# %%
df.iloc[:,0:10].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 87 entries, GSM151259 to GSM151345
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   1007_s_at  87 non-null     object
#  1   1053_at    87 non-null     object
#  2   117_at     87 non-null     object
#  3   121_at     87 non-null     object
#  4   1255_g_at  87 non-null     object
#  5   1294_at    87 non-null     object
#  6   1316_at    87 non-null     object
#  7   1320_at    87 non-null     object
#  8   1405_i_at  87 non-null     object
#  9   1431_at    87 non-null     object
# dtypes: object(10)
# memory usage: 7.5+ KB
